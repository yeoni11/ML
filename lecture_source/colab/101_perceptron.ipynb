# %%
# !pip install danbi

# %%
import danbi as bi
import numpy as np

# %% [markdown]
# # AND / OR / XOR 연산 함수

# %%
# AND 연산
def exAnd(x1, x2):
    if x1 == x2 == 1:
        return 1
    else:
        return 0

# %%
bi.showAsCols(
    exAnd(0, 0), exAnd(0, 1), exAnd(1, 0), exAnd(1, 1)
)

# %%
# OR 연산
def exOr(x1, x2):
    if x1 == x2 == 0:
        return 0
    else:
        return 1

# %%
bi.showAsCols(
    exOr(0, 0), exOr(0, 1), exOr(1, 0), exOr(1, 1)
)

# %%
# XOR 연산
def exXor(x1, x2):
    if x1 == x2:
        return 0
    else:
        return 1

# %%
bi.showAsCols(
    exXor(0, 0), exXor(0, 1), exXor(1, 0), exXor(1, 1)
)

# %% [markdown]
# # Perceptron Cell

# %%
def cell(x1, x2, w1=0.5, w2=0.5, bias=0.5):
    weightSum = x1*w1 + x2*w2 - bias
    #검증 차
    print(weightSum)
    return 0 if weightSum <= 0 else 1

# %%
#검증 차
cell(0, 1, bias=0.4)

# %%
BIAS1 = 0.6
BIAS2 = 0.4
bi.showAsCols(
    "AND", "OR",
    cell(0, 0, bias=BIAS1), cell(0, 0, bias=BIAS2),
    cell(0, 1, bias=BIAS1), cell(0, 1, bias=BIAS2),
    cell(1, 0, bias=BIAS1), cell(1, 0, bias=BIAS2),
    cell(1, 1, bias=BIAS1), cell(1, 1, bias=BIAS2),
    colSize=2, width="30%"
)

# %% [markdown]
# # Learning

# %%
datas = [
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1],
]
labels = [0, 1, 1, 1]

# %%
class Learning(object):
    def __init__(self, learningRate=0.1):
        self.learningRate = learningRate
        self.bias = 0.5
        self.w = np.random.rand(2)
        self.errors = []

    def fit(self, data, label):
        predicted = self.prediction(data)
        error = self._loss(predicted, label)
        self.errors.append(error)
        optimize = self._optimizer(self.learningRate,  error)

    def _hypothesis(self, data, weight, bias):
        return np.matmul(data, weight) - bias

    def _loss(self, predicted, label):
        errors = 0
        for label, pred in zip(label, predicted):
            errors += label - pred
        return errors / len(predicted)

    def _optimizer(self, learningRate, error):
        update = learningRate * error
        self.w += update

    def prediction(self, data):
        production = self._hypothesis(data, self.w, self.bias)
        return np.where(production <= 0, 0, 1)

# %%
learning = Learning(0.01)
print(learning.w)

# %%
learning.prediction(np.array(datas))

# %%
for _ in range(200):
    learning.fit(np.array(datas), np.array(labels))

# %%
print(learning.w)

# %%
learning.prediction(np.array(datas))

# %%
import matplotlib.pyplot as plt
plt.plot(range(1, len(learning.errors)+1), learning.errors, marker=".")
plt.show()

# %% [markdown]
# # 마빈 민스키의 “퍼셉트론 한계” (1969년) 극복

# %%
# AND
bi.showAsCols(
    cell(0, 0, w1=0.5, w2=0.5, bias=0.5),
    cell(0, 1, w1=0.5, w2=0.5, bias=0.5),
    cell(1, 0, w1=0.5, w2=0.5, bias=0.5),
    cell(1, 1, w1=0.5, w2=0.5, bias=0.5),
)

# %%
# OR
bi.showAsCols(
    cell(0, 0, w1=0.5, w2=0.5, bias=0.4),
    cell(0, 1, w1=0.5, w2=0.5, bias=0.4),
    cell(1, 0, w1=0.5, w2=0.5, bias=0.4),
    cell(1, 1, w1=0.5, w2=0.5, bias=0.4),
)
# Out:
# -0.4
# 0.09999999999999998
# 0.09999999999999998
# 0.6
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
# NAND
bi.showAsCols(
    cell(0, 0, w1=-0.5, w2=-0.5, bias=-0.6),
    cell(0, 1, w1=-0.5, w2=-0.5, bias=-0.6),
    cell(1, 0, w1=-0.5, w2=-0.5, bias=-0.6),
    cell(1, 1, w1=-0.5, w2=-0.5, bias=-0.6),
)
# Out:
# 0.6
# 0.09999999999999998
# 0.09999999999999998
# -0.4
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
#p13 - OR모델 1개 + NAND모델 1개
def cellXOR(x1, x2):
    resultNAND = cell(x1, x2, w1=-0.5, w2=-0.5, bias=-0.6)       #p13참조 / cell을 NAND, OR 두 개로 설정한 모습
    resultOR   = cell(x1, x2, w1=0.5, w2=0.5, bias=0.4)          #p13참조
    return cell(resultNAND, resultOR, w1=0.5, w2=0.5, bias=0.5)

# %%
# XOR
bi.showAsCols(
    cellXOR(0, 0),
    cellXOR(0, 1),
    cellXOR(1, 0),
    cellXOR(1, 1)
)
# Out:
# 0.6
# -0.4
# 0.0
# 0.09999999999999998
# 0.09999999999999998
# 0.5
# 0.09999999999999998
# 0.09999999999999998
# 0.5
# -0.4
# 0.6
# 0.0
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
#p13 - NAND모델 4개
def cellXOR(x1, x2):
    resultNAND1 = cell(x1, x2, w1=-0.5, w2=-0.5, bias=-0.6)                    #p13참조 / cell을 NAND 네 개로 설정한 모습
    resultNAND2 = cell(x1, resultNAND1, w1=-0.5, w2=-0.5, bias=-0.6)           #p13참조
    resultNAND3 = cell(x2, resultNAND1, w1=-0.5, w2=-0.5, bias=-0.6)           #p13참조
    resultNAND4 = cell(resultNAND2, resultNAND3, w1=-0.5, w2=-0.5, bias=-0.6)  #p13참조
    return resultNAND4

# %%
# XOR
bi.showAsCols(
    cellXOR(0, 0),
    cellXOR(0, 1),
    cellXOR(1, 0),
    cellXOR(1, 1)
)
# Out:
# 0.6
# 0.09999999999999998
# 0.09999999999999998
# -0.4
# 0.09999999999999998
# 0.09999999999999998
# -0.4
# 0.09999999999999998
# 0.09999999999999998
# -0.4
# 0.09999999999999998
# 0.09999999999999998
# -0.4
# 0.09999999999999998
# 0.09999999999999998
# -0.4
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…
